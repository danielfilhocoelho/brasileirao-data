# %%
from bs4 import BeautifulSoup
import requests
import pandas

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

years = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]


for year in years:
    page = 'https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/formtabelle/wettbewerb/BRA1?saison_id=' + year + '&min=1&max=38'
    site = requests.get(page,headers=headers)
    bs = BeautifulSoup(site.content,'html.parser')
    table = bs.find('div', {'class' : 'responsive-table'})
    x = pandas.read_html(table.prettify())
    tabela_brasileirao = x[0]
    del(tabela_brasileirao['Clube'])
    del(tabela_brasileirao['#'])
    tabela_brasileirao = tabela_brasileirao.rename(columns={"Unnamed: 2": "Clube", "Unnamed: 9": "Pontos", "V":"Jogos" , "E":"V", "D":"E","Golos":"D","+/-":"Gols pró/contra","Pts":"Saldo"  })
    true_year = int(year) + 1
    tabela_brasileirao.to_csv(r'tabela' + str(true_year) + '.csv',index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0

while (count <= 19):
    vitorias = []
    for t in tabelas:
        vitorias.append(t['V'][count])
        plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
        plt.title("Histórico de vitórias do "+ str(count + 1) +" colocado de 2006 a 2018" )
    plt.show()
    count = count + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0
season = 0
for t in tabelas:
    vitorias = []
    count = 0
    while (count <= 19):
        vitorias.append(t['V'][count])
        count = count + 1
    plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
    plt.title("Distribuição de vitórias da temporada "+ str(season + 2006) )
    plt.show()
    season = season + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0

while (count <= 19):
    vitorias = []
    for t in tabelas:
        vitorias.append(t['E'][count])
        plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
        plt.title("Histórico de empates do "+ str(count + 1) +" colocado de 2006 a 2018" )
    plt.show()
    count = count + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0
season = 0
for t in tabelas:
    vitorias = []
    count = 0
    while (count <= 19):
        vitorias.append(t['E'][count])
        count = count + 1
    plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
    plt.title("Distribuição de empates da temporada "+ str(season + 2006) )
    plt.show()
    season = season + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0

while (count <= 19):
    vitorias = []
    for t in tabelas:
        vitorias.append(t['D'][count])
        plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
        plt.title("Histórico de derrotas do "+ str(count + 1) +" colocado de 2006 a 2018" )
    plt.show()
    count = count + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0
season = 0
for t in tabelas:
    vitorias = []
    count = 0
    while (count <= 19):
        vitorias.append(t['D'][count])
        count = count + 1
    plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
    plt.title("Distribuição de derrotas da temporada "+ str(season + 2006) )
    plt.show()
    season = season + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0



while (count <= 19):
    vitorias = []
    for t in tabelas:
        vitorias.append(t['Pontos'][count])
        plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
        plt.title("Histórico de pontos do "+ str(count + 1) +" colocado de 2006 a 2018" )
    plt.show()
    count = count + 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
vitorias = []
count = 0
season = 0
for t in tabelas:
    vitorias = []
    count = 0
    while (count <= 19):
        vitorias.append(t['Pontos'][count])
        count = count + 1
    plt.hist(vitorias,align='left',bins=np.arange(np.min(vitorias),np.max(vitorias)+2),rwidth=0.5,color = 'blue')
    plt.title("Distribuição de pontos da temporada "+ str(season + 2006) )
    plt.show()
    season = season + 1

# %%
escrib#ALGUMAS ESTATÍSTICAS IMPORTANTES

import pandas as pd
import statistics as s


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
dados = []
count = 0

col = ['max', 'min','média','desvio-padrão']
ind = ["V","E","D","Saldo","Pontos"]
df = pd.DataFrame(index= ind ,columns = col )


for j in ind:
    dados = []
    count = 0
    for t in tabelas:
        while (count <= 19):
            dados.append(float(t[j][count]))
            count = count + 1
    df['max'][j] = max(dados)
    df['min'][j] = min(dados)
    df['média'][j] = sum(dados)/len(dados)
    df['desvio-padrão'][j] = s.stdev(dados)
df
# Out:
#        max min  média desvio-padrão
# V       22   7  14.15       4.04286
# E       14   6    9.7       2.36421
# D       24   4  14.15        4.4636
# Saldo   34 -34      0       16.7521
# Pontos  78  28  52.15       12.1103

# %%
# HISTÓRICO DE PONTOS

import pandas as pd
import statistics as s
import matplotlib.pyplot as plt


years = ["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]
tabelas = []
for year in years:   
    tabelas.append(pd.read_csv('tabela' + year + '.csv' ))
    
dados = []
count = 0

ind = ["V","E","D","Saldo","Pontos"]
df = pd.DataFrame(index= ind ,columns = years )

aux = 0

for j in ind:
    dados = []
    count = 0
    aux = 0
    for t in tabelas:
            dados.append(float(t[j].loc[t['Clube'] == 'Flamengo']))
    for x in  dados:
        df[years[aux]][j] = x
        aux = aux + 1
df

dados = []
for x in years:
    dados.append(float(x))
    

plt.scatter(dados,df.loc['Pontos'])
plt.show()
